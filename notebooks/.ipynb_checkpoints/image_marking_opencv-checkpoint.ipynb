# %%
import cv2
import json
from matplotlib import pyplot as plt

# %%
BASE_PATH="/home/shiv/Documents/plants_try/data/camera_images"
DATE_DIR="20221010_225708"
image_number='1'

raw_image_path=f"{BASE_PATH}/{DATE_DIR}/raw/{image_number}.jpg"
raw_image_path=f"{BASE_PATH}/{DATE_DIR}/cv2/{image_number}.png"
seg_image_path=f"{BASE_PATH}/{DATE_DIR}/raw/{image_number}.jpg"
objects_path=f"{BASE_PATH}/{DATE_DIR}/rec_objects/{image_number}.json"

# %%
raw_image_path
# Out:
# '/home/shiv/Documents/plants_try/data/camera_images/20221010_225708/raw/1.jpg'

# %%
image_s = cv2.imread(raw_image_path)
image_r = cv2.rotate(image_s, cv2.ROTATE_180)
image = cv2.flip(image_r, 1)
image=image_s
image.shape
# Out:
# (720, 720, 3)

# %%
image_s
# Out:
# array([[[ 51,  43,  36],
#         [ 49,  41,  34],
#         [ 47,  39,  32],
#         ...,
#         [152, 108,  91],
#         [152, 108,  91],
#         [152, 108,  91]],
#
#        [[ 49,  41,  34],
#         [ 48,  40,  33],
#         [ 48,  40,  33],
#         ...,
#         [152, 108,  91],
#         [152, 108,  91],
#         [152, 108,  91]],
#
#        [[ 46,  38,  31],
#         [ 47,  39,  32],
#         [ 48,  40,  33],
#         ...,
#         [152, 108,  91],
#         [152, 108,  91],
#         [152, 108,  91]],
#
#        ...,
#
#        [[ 82,  95, 141],
#         [ 80,  93, 139],
#         [ 79,  92, 138],
#         ...,
#         [158, 175, 218],
#         [156, 174, 215],
#         [155, 173, 214]],
#
#        [[151, 166, 205],
#         [149, 164, 203],
#         [147, 162, 201],
#         ...,
#         [153, 171, 212],
#         [153, 171, 212],
#         [153, 172, 210]],
#
#        [[172, 188, 225],
#         [169, 185, 222],
#         [167, 183, 220],
#         ...,
#         [ 97, 115, 156],
#         [ 96, 115, 153],
#         [ 95, 114, 152]]], dtype=uint8)

# %%
plt.imshow(image_r)

# %%
plt.imshow(image)

# %%
with open(objects_path, 'r') as file:
    file_content=file.read()

# %%
rec_objs=json.loads(file_content)
rec_objs
# Out:
# {'recognized_objects': [{'id': 333,
#    'position': [3.8551539468921385, 2.13505940640797, 0.7013204414658314],
#    'orientation': [0.0007430874659582476,
#     -1.8622366050963977e-05,
#     0.9999997237370744,
#     3.1365411401011847],
#    'size': [0.6, 0.02012368086359595],
#    'position_on_image': [11, 235],
#    'size_on_image': [22, 122],
#    'number_of_colors': 1,
#    'colors': [0.0, 1.0, 0.0],
#    'model': "b'potted tree'"},
#   {'id': 413,
#    'position': [3.847891732218571, 0.9950025278688868, 0.3306467750698657],
#    'orientation': [0.0007430874829971797,
#     -1.8621643505860364e-05,
#     0.9999997237370754,
#     3.1365430791231605],
#    'size': [0.6000000000000001, 0.6000000000000001],
#    'position_on_image': [184, 299],
#    'size_on_image': [130, 249],
#    'number_of_colors': 1,
#    'colors': [0.0, 1.0, 0.0],
#    'model': "b'potted tree'"},
#   {'id': 493,
#    'position': [2.783240258224789, 0.08040094688691585, 0.3321913994422837],
#    'orientation': [0.0007430872995535231,
#     -1.8629776738877777e-05,
#     0.9999997237370601,
#     3.136521194325525],
#    'size': [0.5999999999999996, 0.6],
#    'position_on_image': [339, 271],
#    'size_on_image': [159, 356],
#    'number_of_colors': 1,
#    'colors': [0.0, 1.0, 0.0],
#    'model': "b'potted tree'"},
#   {'id': 573,
#    'position': [1.7019293425914501, -0.6526863025099154, 0.2826588339111878],
#    'orientation': [0.0007403315707070461,
#     -1.6791773546044292e-05,
#     0.9999997258135632,
#     3.1415726323283937],
#    'size': [0.5999999999999999, 0.49872266092920037],
#    'position_on_image': [606, 259],
#    'size_on_image': [227, 518],
#    'number_of_colors': 1,
#    'colors': [0.0, 1.0, 0.0],
#    'model': "b'potted tree'"},
#   {'id': 963,
#    'position': [0.8702498255358352,
#     -0.21986878365721219,
#     -0.26668328709008593],
#    'orientation': [0.000743087299553517,
#     -1.862977673889823e-05,
#     0.9999997237370601,
#     3.136521194325525],
#    'size': [0.0636815276557925, 0.06350501354670038],
#    'position_on_image': [527, 564],
#    'size_on_image': [60, 107],
#    'number_of_colors': 1,
#    'colors': [0.666667, 0.0, 0.0],
#    'model': "b'can'"},
#   {'id': 974,
#    'position': [0.8727348428031136, 0.2701249146898965, -0.2666668766065171],
#    'orientation': [0.0007430872995535462,
#     -1.862977673889804e-05,
#     0.9999997237370604,
#     3.136521194325525],
#    'size': [0.0636815276557925, 0.06350501354670038],
#    'position_on_image': [155, 563],
#    'size_on_image': [63, 107],
#    'number_of_colors': 1,
#    'colors': [0.666667, 0.0, 0.0],
#    'model': "b'can'"},
#   {'id': 985,
#    'position': [2.0025162047359375, 0.22439473757681364, -0.26834768903474276],
#    'orientation': [0.000743087299553526,
#     -1.862977673885555e-05,
#     0.99999972373706,
#     3.136521194325525],
#    'size': [0.0636815276557925, 0.06350501354670039],
#    'position_on_image': [286, 449],
#    'size_on_image': [23, 43],
#    'number_of_colors': 1,
#    'colors': [0.666667, 0.0, 0.0],
#    'model': "b'can'"},
#   {'id': 996,
#    'position': [2.0951521091420293, 0.7439316233491158, -0.2684640371477984],
#    'orientation': [0.0007430872995535781,
#     -1.8629776738876378e-05,
#     0.9999997237370603,
#     3.136521194325525],
#    'size': [0.06368152765579249, 0.06350501354670038],
#    'position_on_image': [126, 445],
#    'size_on_image': [27, 41],
#    'number_of_colors': 1,
#    'colors': [0.666667, 0.0, 0.0],
#    'model': "b'can'"}]}

# %%
object_to_pick=1
rec_objs['recognized_objects'][object_to_pick]
# Out:
# {'id': 413,
#  'position': [3.847891732218571, 0.9950025278688868, 0.3306467750698657],
#  'orientation': [0.0007430874829971797,
#   -1.8621643505860364e-05,
#   0.9999997237370754,
#   3.1365430791231605],
#  'size': [0.6000000000000001, 0.6000000000000001],
#  'position_on_image': [184, 299],
#  'size_on_image': [130, 249],
#  'number_of_colors': 1,
#  'colors': [0.0, 1.0, 0.0],
#  'model': "b'potted tree'"}

# %%
size = (rec_objs['recognized_objects'][object_to_pick]['size_on_image'][0], 
         rec_objs['recognized_objects'][object_to_pick]['size_on_image'][1])
size
# Out:
# (130, 249)

# %%
start = (rec_objs['recognized_objects'][object_to_pick]['position_on_image'][0], 
         rec_objs['recognized_objects'][object_to_pick]['position_on_image'][1])
start
# Out:
# (184, 299)

# %%
end = (start[0]+size[0], start[1]+size[1])
end
# Out:
# (314, 548)

# %%
image_m = cv2.rectangle(image, start, end, (0,0,255), 2)

# %%
plt.imshow(image_m)

# %%
for obj in rec_objs['recognized_objects']:
    size = (obj['size_on_image'][0], obj['size_on_image'][1])
    start = (obj['position_on_image'][0], obj['position_on_image'][1])
    end = (start[0]+size[0], start[1]+size[1])
    image = cv2.rectangle(image, start, end, (0,0,255), 2)
# Out:
# {'id': 333, 'position': [3.8551539468921385, 2.13505940640797, 0.7013204414658314], 'orientation': [0.0007430874659582476, -1.8622366050963977e-05, 0.9999997237370744, 3.1365411401011847], 'size': [0.6, 0.02012368086359595], 'position_on_image': [11, 235], 'size_on_image': [22, 122], 'number_of_colors': 1, 'colors': [0.0, 1.0, 0.0], 'model': "b'potted tree'"}
# {'id': 413, 'position': [3.847891732218571, 0.9950025278688868, 0.3306467750698657], 'orientation': [0.0007430874829971797, -1.8621643505860364e-05, 0.9999997237370754, 3.1365430791231605], 'size': [0.6000000000000001, 0.6000000000000001], 'position_on_image': [184, 299], 'size_on_image': [130, 249], 'number_of_colors': 1, 'colors': [0.0, 1.0, 0.0], 'model': "b'potted tree'"}
# {'id': 493, 'position': [2.783240258224789, 0.08040094688691585, 0.3321913994422837], 'orientation': [0.0007430872995535231, -1.8629776738877777e-05, 0.9999997237370601, 3.136521194325525], 'size': [0.5999999999999996, 0.6], 'position_on_image': [339, 271], 'size_on_image': [159, 356], 'number_of_colors': 1, 'colors': [0.0, 1.0, 0.0], 'model': "b'potted tree'"}
# {'id': 573, 'position': [1.7019293425914501, -0.6526863025099154, 0.2826588339111878], 'orientation': [0.0007403315707070461, -1.6791773546044292e-05, 0.9999997258135632, 3.1415726323283937], 'size': [0.5999999999999999, 0.49872266092920037], 'position_on_image': [606, 259], 'size_on_image': [227, 518], 'number_of_colors': 1, 'colors': [0.0, 1.0, 0.0], 'model': "b'potted tree'"}
# {'id': 963, 'position': [0.8702498255358352, -0.21986878365721219, -0.26668328709008593], 'orientation': [0.000743087299553517, -1.862977673889823e-05, 0.9999997237370601, 3.136521194325525], 'size': [0.0636815276557925, 0.06350501354670038], 'position_on_image': [527, 564], 'size_on_image': [60, 107], 'number_of_colors': 1, 'colors': [0.666667, 0.0, 0.0], 'model': "b'can'"}
# {'id': 974, 'position': [0.8727348428031136, 0.2701249146898965, -0.2666668766065171], 'orientation': [0.0007430872995535462, -1.862977673889804e-05, 0.9999997237370604, 3.136521194325525], 'size': [0.0636815276557925, 0.06350501354670038], 'position_on_image': [155, 563], 'size_on_image': [63, 107], 'number_of_colors': 1, 'colors': [0.666667, 0.0, 0.0], 'model': "b'can'"}
# {'id': 985, 'position': [2.0025162047359375, 0.22439473757681364, -0.26834768903474276], 'orientation': [0.000743087299553526, -1.862977673885555e-05, 0.99999972373706, 3.136521194325525], 'size': [0.0636815276557925, 0.06350501354670039], 'position_on_image': [286, 449], 'size_on_image': [23, 43], 'number_of_colors': 1, 'colors': [0.666667, 0.0, 0.0], 'model': "b'can'"}
# {'id': 996, 'position': [2.0951521091420293, 0.7439316233491158, -0.2684640371477984], 'orientation': [0.0007430872995535781, -1.8629776738876378e-05, 0.9999997237370603, 3.136521194325525], 'size': [0.06368152765579249, 0.06350501354670038], 'position_on_image': [126, 445], 'size_on_image': [27, 41], 'number_of_colors': 1, 'colors': [0.666667, 0.0, 0.0], 'model': "b'can'"}

# %%
plt.imshow(image_m)

# %%
type(image_m)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('test.png', image_m)
# Out:
# True
